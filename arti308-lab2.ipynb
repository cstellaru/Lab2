# %%
import pandas as pd

# File paths (change folder name if needed)
countries = pd.read_csv('/kaggle/input/olympics-data/CountriesSD.csv')
summer = pd.read_csv('/kaggle/input/olympics-data/SummerSD.csv')
winter = pd.read_csv('/kaggle/input/olympics-data/WinterSD.csv')

# Check shapes
print("Countries shape:", countries.shape)
print("Summer shape:", summer.shape)
print("Winter shape:", winter.shape)

# Preview data
print("\n--- Countries Preview ---")
display(countries.head())

print("\n--- Summer Preview ---")
display(summer.head())

print("\n--- Winter Preview ---")
display(winter.head())

# Column info
print("\n--- Countries Info ---")
countries.info()

print("\n--- Summer Info ---")
summer.info()

print("\n--- Winter Info ---")
winter.info()
# Out:
# Countries shape: (201, 5)
# Summer shape: (31165, 11)
# Winter shape: (5770, 10)
#
# --- Countries Preview ---
#    Unnamed: 0          Country Code  Population  GDP per Capita
# 0           0      Afghanistan  AFG  32526562.0      594.323081
# 1           1          Albania  ALB   2889167.0     3945.217582
# 2           2          Algeria  ALG  39666519.0     4206.031232
# 3           3  American Samoa*  ASA     55538.0             NaN
# 4           4          Andorra  AND     70473.0             NaN
# --- Summer Preview ---
#    Unnamed: 0  Year    City     Sport Discipline            Athlete Code  \
# 0           0  1896  Athens  Aquatics   Swimming       Alfred Hajos  HUN
# 1           1  1896  Athens  Aquatics   Swimming    Otto Herschmann  AUT
# 2           2  1896  Athens  Aquatics   Swimming   Dimitrios Drivas  GRE
# 3           3  1896  Athens  Aquatics   Swimming  Ioannis Malokinis  GRE
# 4           4  1896  Athens  Aquatics   Swimming  Spiridon Chasapis  GRE
#
# ...
